# %% [markdown]
# **Google Drive Bağlantısı**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Kurulumlar**

# %%
# %%shell
# git clone https://github.com/PaddlePaddle/PaddleDetection
# pip install paddlepaddle-gpu pyclipper attrdict gdown -qqq
# cd PaddleDetection
# git checkout develop
# pip install -q -e .
# Out:
# Cloning into 'PaddleDetection'...
# remote: Enumerating objects: 254339, done.
# remote: Total 254339 (delta 0), reused 0 (delta 0), pack-reused 254339
# Receiving objects: 100% (254339/254339), 413.79 MiB | 17.59 MiB/s, done.
# Resolving deltas: 100% (207646/207646), done.
# Updating files: 100% (1619/1619), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.2/585.2 MB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.2/619.2 KB 49.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.5/385.5 KB 41.8 MB/s eta 0:00:00
# error: Your local changes to the following files would be overwritten by checkout:
# 	configs/datasets/coco_detection.yml
# Please commit your changes or stash them before you switch branches.
# Aborting
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 13.2 MB/s eta 0:00:00
# ...

# %%
# !python -m pip install paddlepaddle-gpu==2.2.2 -i https://mirror.baidu.com/pypi/simple
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 MB 2.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: paddlepaddle-gpu
#     Found existing installation: paddlepaddle-gpu 2.4.1
#     Uninstalling paddlepaddle-gpu-2.4.1:
#       Successfully uninstalled paddlepaddle-gpu-2.4.1
# ...

# %%
# %cd PaddleDetection
# !python ppdet/modeling/tests/test_architectures.py
# Out:
# /content/PaddleDetection
# W0126 13:02:15.800804  1934 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 11.6, Runtime API Version: 10.2
# W0126 13:02:15.860105  1934 device_context.cc:465] device: 0, cuDNN Version: 8.1.
# .......
# ----------------------------------------------------------------------
# Ran 7 tests in 8.006s
#
# OK

# %% [markdown]
# **Wandb Kurulum**

# %%
# !pip install wandb -qqq
import wandb
wandb.login()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 KB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 18.2 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.4.1 requires grpcio<2.0dev,>=1.47.0, but you have grpcio 1.41.0 which is incompatible.
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# **Zipten Çıkarma**

# %%
# !cd /content
# !unzip /content/drive/MyDrive/mmdet_data_f1.zip
# Out:
# Archive:  /content/drive/MyDrive/mmdet_data_f1.zip
#    creating: mmdet_data_f1/
#    creating: mmdet_data_f1/images/
#   inflating: mmdet_data_f1/images/006e241d-McLaren05301.jpg
#   inflating: mmdet_data_f1/images/0097a806-RedBull07721.jpg
#   inflating: mmdet_data_f1/images/00b39fc6-french01401.jpg
#   inflating: mmdet_data_f1/images/00c48e11-McLaren05241.jpg
#   inflating: mmdet_data_f1/images/00d09235-Mercedes05221.jpg
#   inflating: mmdet_data_f1/images/00de7c00-McLaren02661.jpg
#   inflating: mmdet_data_f1/images/016eac18-Mercedes05081.jpg
#   inflating: mmdet_data_f1/images/01eede69-McLaren04161.jpg
#   inflating: mmdet_data_f1/images/024d7e5e-scene01021.jpg
#   inflating: mmdet_data_f1/images/02ab0185-McLaren02941.jpg
#   inflating: mmdet_data_f1/images/02fe032b-scene06321.jpg
#   inflating: mmdet_data_f1/images/035583c2-RedBull02341.jpg
#   inflating: mmdet_data_f1/images/040018f1-Mercedes06721.jpg
#   inflating: mmdet_data_f1/images/04018263-Mercedes05021.jpg
# ...

# %% [markdown]
# **Eğitim**

# %%
# !python tools/train.py -c /content/PaddleDetection/configs/yolox/yolox_tiny_300e_coco.yml --use_wandb True -o wandb-project=PaddleDetectionYOLOX --eval -o use_gpu=true --eval
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# W0126 13:11:09.565847  4377 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 11.6, Runtime API Version: 10.2
# W0126 13:11:09.569743  4377 device_context.cc:465] device: 0, cuDNN Version: 8.1.
# wandb: Currently logged in as: yasarniyaz. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.9
# wandb: Run data is saved locally in /content/PaddleDetection/wandb/run-20230126_131122-wyc2ctl0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vibrant-moon-7
# wandb: ⭐️ View project at https://wandb.ai/yasarniyaz/PaddleDetection-tools
# wandb: 🚀 View run at https://wandb.ai/yasarniyaz/PaddleDetection-tools/runs/wyc2ctl0
# ...

# %% [markdown]
# **Test**

# %%
# !python tools/eval.py -c /content/PaddleDetection/configs/yolox/yolox_tiny_300e_coco.yml  -o weights=/content/PaddleDetection/output/yolox_tiny_300e_coco/best_model.pdparams
# Out:
# W0126 14:16:42.478047 21440 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 11.6, Runtime API Version: 10.2
# W0126 14:16:42.496768 21440 device_context.cc:465] device: 0, cuDNN Version: 8.1.
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [01/26 14:16:45] ppdet.utils.checkpoint INFO: Finish loading model weights: /content/PaddleDetection/output/yolox_tiny_300e_coco/best_model.pdparams
# [01/26 14:16:48] ppdet.engine INFO: Eval iter: 0
# [01/26 14:16:54] ppdet.metrics.metrics INFO: The bbox result is saved to bbox.json.
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [01/26 14:16:54] ppdet.metrics.coco_utils INFO: Start evaluate...
# Loading and preparing results...
# DONE (t=0.53s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.84s).
# Accumulating evaluation results...
# ...

# %% [markdown]
# **Resim Üzerinden Test**

# %%
# !python tools/infer.py -c /content/PaddleDetection/configs/yolox/yolox_tiny_300e_coco.yml  -o weights=/content/PaddleDetection/output/yolox_tiny_300e_coco/best_model.pdparams --infer_img=/content/PaddleDetection/mmdet_data_f1/images_val/f4e54bdf-porto00781.jpg --draw_threshold=0.5
# Out:
# W0126 14:18:07.234967 21901 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 11.6, Runtime API Version: 10.2
# W0126 14:18:07.242205 21901 device_context.cc:465] device: 0, cuDNN Version: 8.1.
# [01/26 14:18:09] ppdet.utils.checkpoint INFO: Finish loading model weights: /content/PaddleDetection/output/yolox_tiny_300e_coco/best_model.pdparams
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 100% 1/1 [00:00<00:00,  1.20it/s]
# [01/26 14:18:10] ppdet.engine INFO: Detection bbox results save in output/f4e54bdf-porto00781.jpg

# %% [markdown]
# **Video Üzerinden Test**

# %%
# !python tools/export_model.py -c /content/PaddleDetection/configs/yolox/yolox_tiny_300e_coco.yml -o weights=/content/PaddleDetection/output/yolox_tiny_300e_coco/best_model.pdparams

# %%
# !python /content/PaddleDetection/deploy/python/infer.py --model_dir /content/PaddleDetection/output_inference/yolox_tiny_300e_coco --video_file /content/drive/MyDrive/Videolar/videoplayback_test.mp4 --threshold 0.5
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# class_id:0, confidence:0.5045, left_top:[481.90,466.51],right_bottom:[898.71,663.73]
# class_id:3, confidence:0.6201, left_top:[517.57,474.58],right_bottom:[887.50,675.17]
# class_id:3, confidence:0.5441, left_top:[1307.28,417.19],right_bottom:[1858.98,637.85]
# detect frame: 9600
# Test iter 0
# class_id:3, confidence:0.6221, left_top:[504.16,465.73],right_bottom:[901.29,678.80]
# class_id:3, confidence:0.5894, left_top:[1311.77,422.27],right_bottom:[1853.80,639.63]
# detect frame: 9601
# Test iter 0
# class_id:3, confidence:0.6672, left_top:[513.52,469.83],right_bottom:[894.54,677.14]
# class_id:3, confidence:0.5560, left_top:[1307.09,420.11],right_bottom:[1842.17,637.65]
# detect frame: 9602
# Test iter 0
# class_id:0, confidence:0.5394, left_top:[465.34,473.67],right_bottom:[873.82,664.37]
# class_id:3, confidence:0.6649, left_top:[501.26,477.12],right_bottom:[875.04,677.37]
# ...
